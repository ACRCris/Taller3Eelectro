# %%
import numpy as np
import matplotlib.pyplot as plt

z0 = 376.73 # Impedancia característica del vacío
theta = np.linspace(0.01, 2*np.pi, 10000)
l=6
d=1
k = 2*np.pi/l

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},figsize=(8,8))
ax.plot(theta, (1/16)*((48 + (k*d)**2 + 3*(k*d)*3*np.cos((2*theta)))**2)*(np.sin(theta)**2),linewidth=2)
ax.plot(theta, (1/25)*((k*d)**2)*(-225 + 3136*np.sin(theta)**2 + 3136*np.sin(theta)**4 )*(np.cos(theta)**2), color='r',linewidth=2)
plt.thetagrids([
    0,30,60,90,120,150,210,240,270,300,330, 
])
ax.set_rlabel_position(22.5)  # Move radial labels away from plotted line
ax.grid(True)

#Labels
ax.set_xlabel("Ángulo (°)")
ax.set_ylabel("Potencia de radiada por unidad de angulo solido")
#Legend
ax.legend(["$\lambda$ = Aproximacion potencial exactor", "$\lambda$ = Aproximacion expansion multipolar"], loc='lower right', bbox_to_anchor=(1.1, 1.1))


ax.set_title("Diagrama de radiación comparativo antena esferica para $\lambda$ = 6d")

fig.savefig("DiagramaComparativo.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

z0 = 376.73 # Impedancia característica del vacío
theta = np.linspace(0.01, 2*np.pi, 10000)
l=6
d=1
k = 2*np.pi/l


fig2, ax2 = plt.subplots(figsize=(8,8))
ax2.plot(theta, (1/16)*((48 + (k*d)**2 + 3*(k*d)*3*np.cos((2*theta)))**2)*(np.sin(theta)**2),linewidth=2)
ax2.plot(theta, (1/25)*((k*d)**2)*(-225 + 3136*np.sin(theta)**2 + 3136*np.sin(theta)**4 )*(np.cos(theta)**2), color='r',linewidth=2)

  # Move radial labels away from plotted line
ax2.grid(True)

#Labels
ax2.set_xlabel("Ángulo (°)")
ax2.set_ylabel("Potencia de radiada por unidad de angulo")
#Legend
ax2.legend(["$\lambda$ = Aproximacion potencial exactor", "$\lambda$ = Aproximacion expansion multipolar"], loc='center right', bbox_to_anchor=(1.1, 1.1))


ax2.set_title("Diagrama de radiación antena dipolo para $\lambda$ = d")

fig2.savefig("DiagramaComparativo2.pdf")
plt.show()
